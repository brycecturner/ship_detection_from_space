# %% [markdown]
# <a href="https://colab.research.google.com/github/brycecturner/ship_detection_from_space/blob/main/yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt


random.seed(108)

# %%
os.chdir('/content/drive/MyDrive/ship_detection/')

# %%
#!git clone https://github.com/ultralytics/yolov5 /content/drive/MyDrive/ship_detection/yolov5 # clone

# %%
# !pip install -r requirements.txt

# %%
def extract_info_from_xml(file_dir, using_file):

  root = ET.parse(file_dir + using_file).getroot()

  info_dict = {}

  for elem in root:
    # print(elem.tag)
    if elem.tag == 'filename':
      info_dict['filename'] = elem.text

    for subelem in elem:

      #print(subelem.tag)
      if subelem.tag == 'name':
        info_dict['class'] = subelem.text
      if subelem.tag == 'bndbox':
        box_dict = {}
        for i in subelem:
          box_dict[i.tag] = int(i.text)
        info_dict['bndbox'] = box_dict

  return info_dict

# %%
def convert_to_yolov5(info_dict):
    print_buffer = []
    try:
      class_id = classname_to_id_map[info_dict["class"]]
    except KeyError:
      print("Invalid Class. Must be one from ", class_name_to_id_mapping.keys())
        

    # Transform the bbox co-ordinates as per the format required by YOLO v5
    b_center_x = (info_dict['bndbox']["xmin"] + info_dict['bndbox']["xmax"]) / 2 
    b_center_y = (info_dict['bndbox']["ymin"] + info_dict['bndbox']["ymax"]) / 2
    b_width    = (info_dict['bndbox']["xmax"] - info_dict['bndbox']["xmin"])
    b_height   = (info_dict['bndbox']["ymax"] - info_dict['bndbox']["ymin"])
    b_center_x /= 512 
    b_center_y /= 512 
    b_width    /= 512 
    b_height   /= 512 
    #Write the bbox details to the file 
    print_buffer.append("{} {:.3f} {:.3f} {:.3f} {:.3f}".format(class_id, b_center_x, b_center_y, b_width, b_height))
        
    # Name of the file which we have to save 
    save_file_name = os.path.join("drive/MyDrive/ship_detection/MASATI-v2/annotations", info_dict["filename"].replace("png", "txt"))
    
    # Save the annotation to disk
    print("\n".join(print_buffer), file= open(save_file_name, "w"))

# %%
# For the purposes of this work, it does not matter whether the ship is near the coast or not
# therefore, flatten everything into a single class
classname_to_id_map = {'ship' : 0,
                       'coast_ship' : 0}

# %%
file_dir = '/content/drive/MyDrive/ship_detection/MASATI-v2/coast_ship/'
using_files = os.listdir(file_dir)
using_files[0]

# %%
# This converts the xml files into the requisite yolo format
# all_info = [extract_info_from_xml(file_dir, x) for x in using_files]
#[convert_to_yolov5(x) for x in all_info]

# %%
os.chdir('/content/drive/MyDrive/ship_detection/yolov5')
# !python train.py --img 512 --epochs 3 --data ship_data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=ship_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/drive/MyDrive/ship_detection/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-163-g016e046 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7025023 parameters, 7025023 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/MyDrive/ship_detection/yolo_data/labels.cache... 1620 images, 2500 backgrounds, 0 corrupt: 100% 4120/4120 [00:00<?, ?it/s]
# val: Scanning /content/drive/MyDrive/ship_detection/yolo_data/labels.cache... 1620 images, 2500 backgrounds, 0 corrupt: 100% 4120/4120 [00:00<?, ?it/s]
#
# AutoAnchor: 3.37 anchors/target, 0.972 Best Possible Recall (BPR). Anchors are a poor fit to dataset ⚠️, attempting to improve...
# AutoAnchor: WARNING ⚠️ Extremely small objects found: 12 of 1620 labels are <3 pixels in size
# AutoAnchor: Running kmeans for 9 anchors on 1620 points...
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.7843: 100% 1000/1000 [00:01<00:00, 604.60it/s]
# AutoAnchor: thr=0.25: 0.9994 best possible recall, 6.31 anchors past thr
# AutoAnchor: n=9, img_size=512, metric_all=0.405/0.784-mean/best, past_thr=0.508-mean: 5,5, 7,9, 11,11, 18,14, 13,22, 25,23, 28,42, 50,28, 47,61
# AutoAnchor: Done ✅ (optional: update model *.yaml to use these anchors in the future)
# Plotting labels to runs/train/exp3/labels.jpg...
# Image sizes 512 train, 512 val
# Using 2 dataloader workers
# Logging results to runs/train/exp3
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         0/9         0G     0.1101   0.008799   0.007643          5        512: 100% 258/258 [1:00:53<00:00, 14.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 129/129 [21:40<00:00, 10.08s/it]
#                    all       4120       1620    0.00104      0.757      0.048     0.0129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         1/9         0G    0.07802   0.006904   0.001685          8        512:  86% 222/258 [54:56<08:57, 14.94s/it]

# %%
os.chdir('/content/drive/MyDrive/ship_detection/yolov5')
# !python detect.py --weights runs/train/exp/weights/last.pt --img 512 --conf 0.4 --source ../yolo_data/test/
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=../yolo_data/test/, data=data/coco128.yaml, imgsz=[512, 512], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/drive/MyDrive/ship_detection/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-163-g016e046 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0005.png: 512x512 (no detections), 315.0ms
# image 2/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0006.png: 512x512 (no detections), 245.4ms
# image 3/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0007.png: 512x512 (no detections), 229.2ms
# image 4/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0008.png: 512x512 (no detections), 250.1ms
# image 5/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0011.png: 512x512 (no detections), 242.1ms
# image 6/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0017.png: 512x512 (no detections), 245.7ms
# image 7/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0022.png: 512x512 (no detections), 238.7ms
# image 8/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0032.png: 512x512 (no detections), 240.1ms
# image 9/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0033.png: 512x512 (no detections), 222.8ms
# image 10/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0034.png: 512x512 (no detections), 265.1ms
# image 11/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0036.png: 512x512 (no detections), 240.7ms
# image 12/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0038.png: 512x512 (no detections), 242.4ms
# image 13/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0044.png: 512x512 (no detections), 243.5ms
# image 14/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0055.png: 512x512 (no detections), 243.2ms
# image 15/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0056.png: 512x512 (no detections), 250.2ms
# image 16/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0058.png: 512x512 (no detections), 236.4ms
# image 17/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0062.png: 512x512 (no detections), 247.9ms
# image 18/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0067.png: 512x512 (no detections), 286.8ms
# image 19/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0070.png: 512x512 (no detections), 253.7ms
# image 20/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0073.png: 512x512 (no detections), 256.1ms
# image 21/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0075.png: 512x512 (no detections), 244.6ms
# image 22/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0080.png: 512x512 (no detections), 241.3ms
# image 23/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0083.png: 512x512 (no detections), 242.3ms
# image 24/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0084.png: 512x512 (no detections), 233.2ms
# image 25/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0087.png: 512x512 (no detections), 237.8ms
# image 26/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0093.png: 512x512 (no detections), 251.2ms
# image 27/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0096.png: 512x512 (no detections), 263.1ms
# image 28/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0100.png: 512x512 (no detections), 250.4ms
# image 29/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0103.png: 512x512 (no detections), 244.1ms
# image 30/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0113.png: 512x512 (no detections), 247.4ms
# image 31/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0119.png: 512x512 (no detections), 272.4ms
# image 32/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0122.png: 512x512 (no detections), 241.1ms
# image 33/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0124.png: 512x512 (no detections), 245.9ms
# image 34/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0127.png: 512x512 (no detections), 259.4ms
# image 35/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0131.png: 512x512 (no detections), 334.8ms
# image 36/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0132.png: 512x512 (no detections), 384.1ms
# image 37/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0138.png: 512x512 (no detections), 398.1ms
# image 38/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0141.png: 512x512 (no detections), 387.6ms
# image 39/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0143.png: 512x512 (no detections), 411.1ms
# image 40/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0152.png: 512x512 (no detections), 395.3ms
# image 41/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0155.png: 512x512 (no detections), 416.1ms
# image 42/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0159.png: 512x512 (no detections), 393.6ms
# image 43/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0161.png: 512x512 (no detections), 394.6ms
# image 44/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0164.png: 512x512 (no detections), 394.3ms
# image 45/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0165.png: 512x512 (no detections), 368.8ms
# image 46/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0168.png: 512x512 (no detections), 380.5ms
# image 47/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0169.png: 512x512 (no detections), 324.0ms
# image 48/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0170.png: 512x512 (no detections), 229.6ms
# image 49/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0171.png: 512x512 (no detections), 248.6ms
# image 50/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0177.png: 512x512 (no detections), 262.8ms
# image 51/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0191.png: 512x512 (no detections), 236.7ms
# image 52/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0194.png: 512x512 (no detections), 258.2ms
# image 53/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0196.png: 512x512 (no detections), 247.8ms
# image 54/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0201.png: 512x512 (no detections), 238.0ms
# image 55/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0207.png: 512x512 (no detections), 237.9ms
# image 56/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0209.png: 512x512 (no detections), 244.7ms
# image 57/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0213.png: 512x512 (no detections), 253.2ms
# image 58/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0216.png: 512x512 (no detections), 246.8ms
# image 59/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0217.png: 512x512 (no detections), 264.4ms
# image 60/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0223.png: 512x512 (no detections), 260.1ms
# image 61/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0226.png: 512x512 (no detections), 252.3ms
# image 62/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0233.png: 512x512 (no detections), 246.4ms
# image 63/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0234.png: 512x512 (no detections), 243.7ms
# image 64/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0240.png: 512x512 (no detections), 229.2ms
# image 65/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0245.png: 512x512 (no detections), 247.3ms
# image 66/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0253.png: 512x512 (no detections), 252.7ms
# image 67/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0260.png: 512x512 (no detections), 238.8ms
# image 68/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0263.png: 512x512 (no detections), 280.1ms
# image 69/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0268.png: 512x512 (no detections), 245.3ms
# image 70/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0276.png: 512x512 (no detections), 244.7ms
# image 71/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0278.png: 512x512 (no detections), 243.9ms
# image 72/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0281.png: 512x512 (no detections), 258.9ms
# image 73/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0283.png: 512x512 (no detections), 262.2ms
# image 74/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0298.png: 512x512 (no detections), 247.1ms
# image 75/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0302.png: 512x512 (no detections), 243.1ms
# image 76/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0304.png: 512x512 (no detections), 277.8ms
# image 77/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0305.png: 512x512 (no detections), 247.8ms
# image 78/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0307.png: 512x512 (no detections), 235.1ms
# image 79/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0309.png: 512x512 (no detections), 271.1ms
# image 80/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0313.png: 512x512 (no detections), 257.4ms
# image 81/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0314.png: 512x512 (no detections), 323.9ms
# image 82/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0315.png: 512x512 (no detections), 378.9ms
# image 83/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0317.png: 512x512 (no detections), 363.3ms
# image 84/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0319.png: 512x512 (no detections), 385.6ms
# image 85/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0321.png: 512x512 (no detections), 376.9ms
# image 86/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0328.png: 512x512 (no detections), 401.0ms
# image 87/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0329.png: 512x512 (no detections), 402.9ms
# image 88/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0330.png: 512x512 (no detections), 386.9ms
# image 89/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0343.png: 512x512 (no detections), 406.1ms
# image 90/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0346.png: 512x512 (no detections), 391.9ms
# image 91/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0362.png: 512x512 (no detections), 385.0ms
# image 92/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0368.png: 512x512 (no detections), 393.2ms
# image 93/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0372.png: 512x512 (no detections), 325.0ms
# image 94/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0379.png: 512x512 (no detections), 248.9ms
# image 95/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0386.png: 512x512 (no detections), 261.4ms
# image 96/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0388.png: 512x512 (no detections), 250.6ms
# image 97/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0390.png: 512x512 (no detections), 251.7ms
# image 98/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0397.png: 512x512 (no detections), 263.3ms
# image 99/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0399.png: 512x512 (no detections), 242.9ms
# image 100/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0400.png: 512x512 (no detections), 259.1ms
# image 101/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0402.png: 512x512 (no detections), 244.2ms
# image 102/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0405.png: 512x512 (no detections), 257.0ms
# image 103/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0420.png: 512x512 (no detections), 278.6ms
# image 104/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0423.png: 512x512 (no detections), 243.1ms
# image 105/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0425.png: 512x512 (no detections), 256.4ms
# image 106/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0431.png: 512x512 (no detections), 267.6ms
# image 107/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0434.png: 512x512 (no detections), 258.0ms
# image 108/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0443.png: 512x512 (no detections), 234.2ms
# image 109/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0449.png: 512x512 (no detections), 252.5ms
# image 110/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0466.png: 512x512 (no detections), 251.4ms
# image 111/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0470.png: 512x512 (no detections), 241.5ms
# image 112/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0472.png: 512x512 (no detections), 255.3ms
# image 113/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0474.png: 512x512 (no detections), 242.0ms
# image 114/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0478.png: 512x512 (no detections), 245.0ms
# image 115/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0481.png: 512x512 (no detections), 228.1ms
# image 116/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0488.png: 512x512 (no detections), 297.3ms
# image 117/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0491.png: 512x512 (no detections), 261.6ms
# image 118/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0492.png: 512x512 (no detections), 257.1ms
# image 119/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0493.png: 512x512 (no detections), 262.0ms
# image 120/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0496.png: 512x512 (no detections), 256.5ms
# image 121/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0498.png: 512x512 (no detections), 238.0ms
# image 122/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0514.png: 512x512 (no detections), 232.1ms
# image 123/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0515.png: 512x512 (no detections), 236.1ms
# image 124/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0517.png: 512x512 (no detections), 236.5ms
# image 125/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0521.png: 512x512 (no detections), 243.6ms
# image 126/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0524.png: 512x512 (no detections), 245.7ms
# image 127/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0526.png: 512x512 (no detections), 333.8ms
# image 128/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0529.png: 512x512 (no detections), 408.1ms
# image 129/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0540.png: 512x512 (no detections), 369.4ms
# image 130/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0548.png: 512x512 (no detections), 365.1ms
# image 131/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0550.png: 512x512 (no detections), 389.8ms
# image 132/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0552.png: 512x512 (no detections), 370.8ms
# image 133/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0553.png: 512x512 (no detections), 377.8ms
# image 134/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0556.png: 512x512 (no detections), 397.9ms
# image 135/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0557.png: 512x512 (no detections), 391.3ms
# image 136/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0558.png: 512x512 (no detections), 391.9ms
# image 137/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0561.png: 512x512 (no detections), 364.6ms
# image 138/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0563.png: 512x512 (no detections), 399.5ms
# image 139/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0564.png: 512x512 (no detections), 355.9ms
# image 140/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0565.png: 512x512 (no detections), 252.9ms
# image 141/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0570.png: 512x512 (no detections), 253.5ms
# image 142/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0571.png: 512x512 (no detections), 233.7ms
# image 143/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0581.png: 512x512 (no detections), 243.7ms
# image 144/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0584.png: 512x512 (no detections), 234.1ms
# image 145/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0592.png: 512x512 (no detections), 226.7ms
# image 146/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0595.png: 512x512 (no detections), 236.4ms
# image 147/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0603.png: 512x512 (no detections), 245.5ms
# image 148/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0608.png: 512x512 (no detections), 247.8ms
# image 149/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0611.png: 512x512 (no detections), 237.2ms
# image 150/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0612.png: 512x512 (no detections), 245.9ms
# image 151/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0613 (1).png: 512x512 (no detections), 236.1ms
# image 152/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0613.png: 512x512 (no detections), 240.7ms
# image 153/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0615.png: 512x512 (no detections), 249.5ms
# image 154/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0623.png: 512x512 (no detections), 241.2ms
# image 155/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0633.png: 512x512 (no detections), 250.9ms
# image 156/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0637.png: 512x512 (no detections), 235.5ms
# image 157/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0639.png: 512x512 (no detections), 234.9ms
# image 158/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0640.png: 512x512 (no detections), 238.1ms
# image 159/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0652.png: 512x512 (no detections), 250.5ms
# image 160/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0653.png: 512x512 (no detections), 225.0ms
# image 161/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0654.png: 512x512 (no detections), 230.9ms
# image 162/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0656.png: 512x512 (no detections), 253.1ms
# image 163/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0660.png: 512x512 (no detections), 226.1ms
# image 164/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0665.png: 512x512 (no detections), 233.1ms
# image 165/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0669.png: 512x512 (no detections), 260.2ms
# image 166/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0672.png: 512x512 (no detections), 252.7ms
# image 167/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0675.png: 512x512 (no detections), 227.4ms
# image 168/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0684.png: 512x512 (no detections), 229.6ms
# image 169/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0699.png: 512x512 (no detections), 257.1ms
# image 170/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0702.png: 512x512 (no detections), 238.8ms
# image 171/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0704.png: 512x512 (no detections), 253.4ms
# image 172/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0706.png: 512x512 (no detections), 244.0ms
# image 173/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0711.png: 512x512 (no detections), 254.3ms
# image 174/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0713.png: 512x512 (no detections), 340.1ms
# image 175/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0714.png: 512x512 (no detections), 392.2ms
# image 176/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0717.png: 512x512 (no detections), 377.7ms
# image 177/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0720.png: 512x512 (no detections), 443.5ms
# image 178/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0721.png: 512x512 (no detections), 399.5ms
# image 179/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0726.png: 512x512 (no detections), 401.6ms
# image 180/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0728.png: 512x512 (no detections), 377.2ms
# image 181/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0729.png: 512x512 (no detections), 380.7ms
# image 182/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0730.png: 512x512 (no detections), 373.8ms
# image 183/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0736.png: 512x512 (no detections), 390.2ms
# image 184/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0737.png: 512x512 (no detections), 410.5ms
# image 185/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0738.png: 512x512 (no detections), 386.2ms
# image 186/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0739.png: 512x512 (no detections), 285.8ms
# image 187/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0740.png: 512x512 (no detections), 237.5ms
# image 188/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0741.png: 512x512 (no detections), 262.5ms
# image 189/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0744.png: 512x512 (no detections), 240.4ms
# image 190/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0745.png: 512x512 (no detections), 238.6ms
# image 191/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0749.png: 512x512 (no detections), 235.9ms
# image 192/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0751.png: 512x512 (no detections), 293.3ms
# image 193/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0752.png: 512x512 (no detections), 264.0ms
# image 194/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0760.png: 512x512 (no detections), 240.5ms
# image 195/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0761.png: 512x512 (no detections), 246.2ms
# image 196/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0763.png: 512x512 (no detections), 251.7ms
# image 197/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0766.png: 512x512 (no detections), 244.5ms
# image 198/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0768.png: 512x512 (no detections), 247.3ms
# image 199/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0774.png: 512x512 (no detections), 243.0ms
# image 200/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0780.png: 512x512 (no detections), 240.6ms
# image 201/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0782.png: 512x512 (no detections), 245.7ms
# image 202/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0787.png: 512x512 (no detections), 272.1ms
# image 203/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0788.png: 512x512 (no detections), 248.9ms
# image 204/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0794.png: 512x512 (no detections), 256.0ms
# image 205/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0795.png: 512x512 (no detections), 237.8ms
# image 206/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0802.png: 512x512 (no detections), 231.9ms
# image 207/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0806.png: 512x512 (no detections), 252.8ms
# image 208/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0807.png: 512x512 (no detections), 246.6ms
# image 209/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0808.png: 512x512 (no detections), 263.1ms
# image 210/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0826.png: 512x512 (no detections), 243.8ms
# image 211/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0827.png: 512x512 (no detections), 242.8ms
# image 212/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0830.png: 512x512 (no detections), 258.5ms
# image 213/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0842.png: 512x512 (no detections), 244.7ms
# image 214/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0848.png: 512x512 (no detections), 232.2ms
# image 215/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0850.png: 512x512 (no detections), 246.1ms
# image 216/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0855.png: 512x512 (no detections), 251.5ms
# image 217/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0857.png: 512x512 (no detections), 245.5ms
# image 218/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0858.png: 512x512 (no detections), 244.1ms
# image 219/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0865.png: 512x512 (no detections), 257.1ms
# image 220/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0866.png: 512x512 (no detections), 345.7ms
# image 221/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0877.png: 512x512 (no detections), 364.4ms
# image 222/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0883.png: 512x512 (no detections), 366.4ms
# image 223/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0885.png: 512x512 (no detections), 381.7ms
# image 224/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0886.png: 512x512 (no detections), 373.3ms
# image 225/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0889.png: 512x512 (no detections), 402.8ms
# image 226/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0892.png: 512x512 (no detections), 367.4ms
# image 227/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0897.png: 512x512 (no detections), 372.9ms
# image 228/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0898.png: 512x512 (no detections), 368.1ms
# image 229/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0902.png: 512x512 (no detections), 371.3ms
# image 230/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0907.png: 512x512 (no detections), 388.8ms
# image 231/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0910.png: 512x512 (no detections), 357.1ms
# image 232/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0914.png: 512x512 (no detections), 390.2ms
# image 233/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0917.png: 512x512 (no detections), 288.2ms
# image 234/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0923.png: 512x512 (no detections), 235.6ms
# image 235/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0924.png: 512x512 (no detections), 236.1ms
# image 236/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0927.png: 512x512 (no detections), 227.9ms
# image 237/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0930.png: 512x512 (no detections), 247.0ms
# image 238/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0931.png: 512x512 (no detections), 256.1ms
# image 239/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0936.png: 512x512 (no detections), 265.3ms
# image 240/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0941.png: 512x512 (no detections), 253.0ms
# image 241/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0943.png: 512x512 (no detections), 242.5ms
# image 242/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0963.png: 512x512 (no detections), 255.1ms
# image 243/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0964.png: 512x512 (no detections), 230.6ms
# image 244/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0978.png: 512x512 (no detections), 257.4ms
# image 245/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0979.png: 512x512 (no detections), 255.3ms
# image 246/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0983.png: 512x512 (no detections), 239.9ms
# image 247/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0987.png: 512x512 (no detections), 248.6ms
# image 248/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0992.png: 512x512 (no detections), 237.6ms
# image 249/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c0994.png: 512x512 (no detections), 254.8ms
# image 250/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1005.png: 512x512 (no detections), 238.9ms
# image 251/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1011.png: 512x512 (no detections), 227.5ms
# image 252/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1013.png: 512x512 (no detections), 231.8ms
# image 253/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1014.png: 512x512 (no detections), 256.1ms
# image 254/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1021.png: 512x512 (no detections), 237.8ms
# image 255/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1023.png: 512x512 (no detections), 248.2ms
# image 256/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1025.png: 512x512 (no detections), 256.1ms
# image 257/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1026.png: 512x512 (no detections), 252.2ms
# image 258/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1034.png: 512x512 (no detections), 237.6ms
# image 259/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1036.png: 512x512 (no detections), 239.0ms
# image 260/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1037.png: 512x512 (no detections), 270.2ms
# image 261/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1038.png: 512x512 (no detections), 248.8ms
# image 262/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1039.png: 512x512 (no detections), 250.5ms
# image 263/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1042.png: 512x512 (no detections), 249.1ms
# image 264/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1052.png: 512x512 (no detections), 246.0ms
# image 265/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1056.png: 512x512 (no detections), 240.4ms
# image 266/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1067.png: 512x512 (no detections), 224.0ms
# image 267/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1068.png: 512x512 (no detections), 281.3ms
# image 268/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1069.png: 512x512 (no detections), 403.0ms
# image 269/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1070.png: 512x512 (no detections), 410.1ms
# image 270/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1071.png: 512x512 (no detections), 381.2ms
# image 271/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1077.png: 512x512 (no detections), 385.7ms
# image 272/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1079.png: 512x512 (no detections), 379.8ms
# image 273/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1081.png: 512x512 (no detections), 363.5ms
# image 274/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1084.png: 512x512 (no detections), 383.3ms
# image 275/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1085.png: 512x512 (no detections), 358.2ms
# image 276/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1091.png: 512x512 (no detections), 413.5ms
# image 277/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1092.png: 512x512 (no detections), 382.8ms
# image 278/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1105.png: 512x512 (no detections), 374.8ms
# image 279/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1106.png: 512x512 (no detections), 389.4ms
# image 280/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1120.png: 512x512 (no detections), 279.3ms
# image 281/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1121.png: 512x512 (no detections), 249.3ms
# image 282/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1123.png: 512x512 (no detections), 241.9ms
# image 283/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1131.png: 512x512 (no detections), 251.4ms
# image 284/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/c1132.png: 512x512 (no detections), 242.6ms
# image 285/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0011.png: 512x512 (no detections), 249.3ms
# image 286/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0015.png: 512x512 (no detections), 259.5ms
# image 287/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0016.png: 512x512 (no detections), 245.6ms
# image 288/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0026.png: 512x512 (no detections), 242.3ms
# image 289/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0028.png: 512x512 (no detections), 240.3ms
# image 290/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0029.png: 512x512 (no detections), 226.7ms
# image 291/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0030.png: 512x512 (no detections), 238.8ms
# image 292/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0033.png: 512x512 (no detections), 256.2ms
# image 293/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0046.png: 512x512 (no detections), 247.8ms
# image 294/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0052.png: 512x512 (no detections), 241.0ms
# image 295/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0055.png: 512x512 (no detections), 245.8ms
# image 296/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0061.png: 512x512 (no detections), 257.9ms
# image 297/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0064.png: 512x512 (no detections), 249.6ms
# image 298/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0066.png: 512x512 (no detections), 246.9ms
# image 299/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0071.png: 512x512 (no detections), 263.7ms
# image 300/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0072.png: 512x512 (no detections), 235.2ms
# image 301/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0073.png: 512x512 (no detections), 240.7ms
# image 302/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0079.png: 512x512 (no detections), 249.5ms
# image 303/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0086.png: 512x512 (no detections), 240.3ms
# image 304/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0092.png: 512x512 (no detections), 242.7ms
# image 305/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0094.png: 512x512 (no detections), 248.5ms
# image 306/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0100.png: 512x512 (no detections), 251.1ms
# image 307/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0104.png: 512x512 (no detections), 253.7ms
# image 308/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0108.png: 512x512 (no detections), 240.0ms
# image 309/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0116.png: 512x512 (no detections), 252.1ms
# image 310/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0117.png: 512x512 (no detections), 236.4ms
# image 311/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0120.png: 512x512 (no detections), 227.6ms
# image 312/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0132.png: 512x512 (no detections), 249.4ms
# image 313/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0140.png: 512x512 (no detections), 285.2ms
# image 314/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0142.png: 512x512 (no detections), 347.7ms
# image 315/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0143.png: 512x512 (no detections), 397.8ms
# image 316/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0146.png: 512x512 (no detections), 373.5ms
# image 317/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0151.png: 512x512 (no detections), 394.1ms
# image 318/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0158.png: 512x512 (no detections), 392.0ms
# image 319/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0163.png: 512x512 (no detections), 397.5ms
# image 320/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0164.png: 512x512 (no detections), 380.8ms
# image 321/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0165.png: 512x512 (no detections), 403.5ms
# image 322/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0173.png: 512x512 (no detections), 376.7ms
# image 323/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0179.png: 512x512 (no detections), 396.8ms
# image 324/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0180.png: 512x512 (no detections), 374.4ms
# image 325/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0181.png: 512x512 (no detections), 389.3ms
# image 326/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0182.png: 512x512 (no detections), 355.2ms
# image 327/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0193.png: 512x512 (no detections), 248.3ms
# image 328/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0200.png: 512x512 (no detections), 248.4ms
# image 329/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0205.png: 512x512 (no detections), 262.2ms
# image 330/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0207.png: 512x512 (no detections), 248.2ms
# image 331/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0211.png: 512x512 (no detections), 244.5ms
# image 332/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0224.png: 512x512 (no detections), 235.6ms
# image 333/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0227.png: 512x512 (no detections), 237.0ms
# image 334/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0233.png: 512x512 (no detections), 241.5ms
# image 335/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0237.png: 512x512 (no detections), 246.9ms
# image 336/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0240.png: 512x512 (no detections), 259.9ms
# image 337/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0241.png: 512x512 (no detections), 245.9ms
# image 338/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0242.png: 512x512 (no detections), 257.1ms
# image 339/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0244.png: 512x512 (no detections), 257.0ms
# image 340/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0245.png: 512x512 (no detections), 239.1ms
# image 341/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0247.png: 512x512 (no detections), 237.3ms
# image 342/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0257.png: 512x512 (no detections), 275.9ms
# image 343/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0258.png: 512x512 (no detections), 255.5ms
# image 344/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0274.png: 512x512 (no detections), 244.0ms
# image 345/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0278.png: 512x512 (no detections), 256.7ms
# image 346/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0283.png: 512x512 (no detections), 250.2ms
# image 347/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0291.png: 512x512 (no detections), 256.0ms
# image 348/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0293.png: 512x512 (no detections), 252.0ms
# image 349/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0296.png: 512x512 (no detections), 255.4ms
# image 350/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0297.png: 512x512 (no detections), 249.2ms
# image 351/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0311.png: 512x512 (no detections), 235.3ms
# image 352/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0320.png: 512x512 (no detections), 247.2ms
# image 353/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0322.png: 512x512 (no detections), 254.8ms
# image 354/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0323.png: 512x512 (no detections), 236.3ms
# image 355/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0327.png: 512x512 (no detections), 251.3ms
# image 356/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0330.png: 512x512 (no detections), 244.9ms
# image 357/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0331.png: 512x512 (no detections), 240.3ms
# image 358/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0333.png: 512x512 (no detections), 238.6ms
# image 359/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0337.png: 512x512 (no detections), 258.7ms
# image 360/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0342.png: 512x512 (no detections), 324.8ms
# image 361/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0347.png: 512x512 (no detections), 436.9ms
# image 362/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0348.png: 512x512 (no detections), 367.5ms
# image 363/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0351.png: 512x512 (no detections), 419.3ms
# image 364/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0358.png: 512x512 (no detections), 377.8ms
# image 365/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0365.png: 512x512 (no detections), 404.1ms
# image 366/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0366.png: 512x512 (no detections), 383.3ms
# image 367/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0372.png: 512x512 (no detections), 364.7ms
# image 368/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0382.png: 512x512 (no detections), 393.3ms
# image 369/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0392.png: 512x512 (no detections), 384.0ms
# image 370/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0398.png: 512x512 (no detections), 415.3ms
# image 371/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0399.png: 512x512 (no detections), 377.3ms
# image 372/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0401.png: 512x512 (no detections), 334.2ms
# image 373/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0402.png: 512x512 (no detections), 240.5ms
# image 374/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0406.png: 512x512 (no detections), 254.8ms
# image 375/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0407.png: 512x512 (no detections), 264.4ms
# image 376/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0414.png: 512x512 (no detections), 236.7ms
# image 377/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0416.png: 512x512 (no detections), 252.7ms
# image 378/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0418.png: 512x512 (no detections), 253.6ms
# image 379/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0422.png: 512x512 (no detections), 253.0ms
# image 380/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0425.png: 512x512 (no detections), 251.6ms
# image 381/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0434.png: 512x512 (no detections), 255.8ms
# image 382/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0441.png: 512x512 (no detections), 228.7ms
# image 383/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0443.png: 512x512 (no detections), 229.0ms
# image 384/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0456.png: 512x512 (no detections), 251.4ms
# image 385/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0466.png: 512x512 (no detections), 255.8ms
# image 386/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0472.png: 512x512 (no detections), 262.6ms
# image 387/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0474.png: 512x512 (no detections), 263.7ms
# image 388/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0475.png: 512x512 (no detections), 252.3ms
# image 389/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0479.png: 512x512 (no detections), 231.8ms
# image 390/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0481.png: 512x512 (no detections), 247.3ms
# image 391/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0482.png: 512x512 (no detections), 257.2ms
# image 392/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0484.png: 512x512 (no detections), 250.5ms
# image 393/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0491.png: 512x512 (no detections), 266.9ms
# image 394/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0492.png: 512x512 (no detections), 248.7ms
# image 395/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0493.png: 512x512 (no detections), 252.1ms
# image 396/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0494.png: 512x512 (no detections), 248.4ms
# image 397/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0495.png: 512x512 (no detections), 236.8ms
# image 398/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0496.png: 512x512 (no detections), 245.2ms
# image 399/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0500.png: 512x512 (no detections), 243.0ms
# image 400/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0504.png: 512x512 (no detections), 244.2ms
# image 401/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0508.png: 512x512 (no detections), 242.4ms
# image 402/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0519.png: 512x512 (no detections), 237.1ms
# image 403/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0524.png: 512x512 (no detections), 243.2ms
# image 404/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0525.png: 512x512 (no detections), 246.0ms
# image 405/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0526.png: 512x512 (no detections), 241.9ms
# image 406/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0527.png: 512x512 (no detections), 300.5ms
# image 407/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0536.png: 512x512 (no detections), 405.0ms
# image 408/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0537.png: 512x512 (no detections), 389.0ms
# image 409/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0539.png: 512x512 (no detections), 384.8ms
# image 410/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0541.png: 512x512 (no detections), 373.9ms
# image 411/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0544.png: 512x512 (no detections), 410.2ms
# image 412/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0550.png: 512x512 (no detections), 383.0ms
# image 413/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0551.png: 512x512 (no detections), 381.9ms
# image 414/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0554.png: 512x512 (no detections), 384.8ms
# image 415/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0558.png: 512x512 (no detections), 393.9ms
# image 416/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0560.png: 512x512 (no detections), 376.7ms
# image 417/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0563.png: 512x512 (no detections), 367.0ms
# image 418/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0565.png: 512x512 (no detections), 356.1ms
# image 419/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0567.png: 512x512 (no detections), 238.9ms
# image 420/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0569.png: 512x512 (no detections), 259.2ms
# image 421/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0570.png: 512x512 (no detections), 248.7ms
# image 422/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0574.png: 512x512 (no detections), 237.8ms
# image 423/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/l0575.png: 512x512 (no detections), 245.4ms
# ...
# image 1053/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0396.png: 512x512 (no detections), 277.8ms
# image 1054/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0400.png: 512x512 (no detections), 303.7ms
# image 1055/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0403.png: 512x512 (no detections), 238.6ms
# image 1056/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0406.png: 512x512 (no detections), 247.0ms
# image 1057/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0421.png: 512x512 (no detections), 244.1ms
# image 1058/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0428.png: 512x512 (no detections), 241.9ms
# image 1059/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0434.png: 512x512 (no detections), 245.8ms
# image 1060/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0440.png: 512x512 (no detections), 237.0ms
# image 1061/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0441.png: 512x512 (no detections), 271.6ms
# image 1062/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0443.png: 512x512 (no detections), 241.1ms
# image 1063/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0450.png: 512x512 (no detections), 269.4ms
# image 1064/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0453.png: 512x512 (no detections), 387.5ms
# image 1065/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0458.png: 512x512 (no detections), 381.1ms
# image 1066/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0462.png: 512x512 (no detections), 396.5ms
# image 1067/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0466.png: 512x512 (no detections), 398.3ms
# image 1068/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0472.png: 512x512 (no detections), 373.0ms
# image 1069/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0473.png: 512x512 (no detections), 402.8ms
# image 1070/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0476.png: 512x512 (no detections), 419.7ms
# image 1071/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0479.png: 512x512 (no detections), 409.7ms
# image 1072/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0480.png: 512x512 (no detections), 396.0ms
# image 1073/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0481.png: 512x512 (no detections), 391.2ms
# image 1074/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0488.png: 512x512 (no detections), 372.9ms
# image 1075/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0492.png: 512x512 (no detections), 370.6ms
# image 1076/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0494.png: 512x512 (no detections), 259.5ms
# image 1077/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0500.png: 512x512 (no detections), 234.2ms
# image 1078/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0501.png: 512x512 (no detections), 238.5ms
# image 1079/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0504.png: 512x512 (no detections), 235.8ms
# image 1080/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0511.png: 512x512 (no detections), 254.3ms
# image 1081/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0514.png: 512x512 (no detections), 248.8ms
# image 1082/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0517.png: 512x512 (no detections), 226.8ms
# image 1083/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0523.png: 512x512 (no detections), 263.5ms
# image 1084/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0524.png: 512x512 (no detections), 231.8ms
# image 1085/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0538.png: 512x512 (no detections), 240.8ms
# image 1086/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0542.png: 512x512 (no detections), 235.9ms
# image 1087/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0550.png: 512x512 (no detections), 266.4ms
# image 1088/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0554.png: 512x512 (no detections), 228.1ms
# image 1089/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0563.png: 512x512 (no detections), 254.2ms
# image 1090/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0568.png: 512x512 (no detections), 238.4ms
# image 1091/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0569.png: 512x512 (no detections), 240.6ms
# image 1092/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0574.png: 512x512 (no detections), 234.2ms
# image 1093/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0579.png: 512x512 (no detections), 228.3ms
# image 1094/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0580.png: 512x512 (no detections), 249.3ms
# image 1095/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0600.png: 512x512 (no detections), 259.1ms
# image 1096/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0601.png: 512x512 (no detections), 236.4ms
# image 1097/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0602.png: 512x512 (no detections), 257.3ms
# image 1098/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0605.png: 512x512 (no detections), 245.7ms
# image 1099/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0607.png: 512x512 (no detections), 244.0ms
# image 1100/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0609.png: 512x512 (no detections), 257.4ms
# image 1101/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0610.png: 512x512 (no detections), 238.5ms
# image 1102/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0613.png: 512x512 (no detections), 232.9ms
# image 1103/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0616.png: 512x512 (no detections), 268.0ms
# image 1104/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0623.png: 512x512 (no detections), 260.0ms
# image 1105/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0634.png: 512x512 (no detections), 258.2ms
# image 1106/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0635.png: 512x512 (no detections), 250.2ms
# image 1107/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0638.png: 512x512 (no detections), 231.6ms
# image 1108/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0640.png: 512x512 (no detections), 243.2ms
# image 1109/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0641.png: 512x512 (no detections), 236.0ms
# image 1110/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0642.png: 512x512 (no detections), 252.4ms
# image 1111/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0644.png: 512x512 (no detections), 370.5ms
# image 1112/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0645.png: 512x512 (no detections), 376.9ms
# image 1113/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0646.png: 512x512 (no detections), 394.0ms
# image 1114/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0649.png: 512x512 (no detections), 392.4ms
# image 1115/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0651.png: 512x512 (no detections), 373.5ms
# image 1116/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0655.png: 512x512 (no detections), 414.7ms
# image 1117/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0664.png: 512x512 (no detections), 394.9ms
# image 1118/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0666.png: 512x512 (no detections), 452.4ms
# image 1119/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0669.png: 512x512 (no detections), 403.7ms
# image 1120/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0670.png: 512x512 (no detections), 370.7ms
# image 1121/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0672.png: 512x512 (no detections), 376.2ms
# image 1122/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0681.png: 512x512 (no detections), 380.4ms
# image 1123/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0686.png: 512x512 (no detections), 334.6ms
# image 1124/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0687.png: 512x512 (no detections), 259.0ms
# image 1125/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0693.png: 512x512 (no detections), 231.5ms
# image 1126/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0697.png: 512x512 (no detections), 268.2ms
# image 1127/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0701.png: 512x512 (no detections), 248.3ms
# image 1128/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0711.png: 512x512 (no detections), 238.7ms
# image 1129/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0712.png: 512x512 (no detections), 235.1ms
# image 1130/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0713.png: 512x512 (no detections), 261.7ms
# image 1131/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0715.png: 512x512 (no detections), 225.2ms
# image 1132/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0717.png: 512x512 (no detections), 232.3ms
# image 1133/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0718.png: 512x512 (no detections), 241.4ms
# image 1134/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0721.png: 512x512 (no detections), 269.6ms
# image 1135/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0723.png: 512x512 (no detections), 234.3ms
# image 1136/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0730.png: 512x512 (no detections), 234.3ms
# image 1137/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0759.png: 512x512 (no detections), 267.4ms
# image 1138/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0763.png: 512x512 (no detections), 229.4ms
# image 1139/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0769.png: 512x512 (no detections), 235.7ms
# image 1140/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0772.png: 512x512 (no detections), 236.4ms
# image 1141/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0780.png: 512x512 (no detections), 246.2ms
# image 1142/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0783.png: 512x512 (no detections), 252.9ms
# image 1143/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0786.png: 512x512 (no detections), 245.8ms
# image 1144/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0811.png: 512x512 (no detections), 237.9ms
# image 1145/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0814.png: 512x512 (no detections), 237.6ms
# image 1146/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0815.png: 512x512 (no detections), 244.4ms
# image 1147/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0819.png: 512x512 (no detections), 235.1ms
# image 1148/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0820.png: 512x512 (no detections), 239.7ms
# image 1149/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0834.png: 512x512 (no detections), 249.4ms
# image 1150/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0836.png: 512x512 (no detections), 236.5ms
# image 1151/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0839.png: 512x512 (no detections), 239.2ms
# image 1152/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0843.png: 512x512 (no detections), 264.9ms
# image 1153/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0844.png: 512x512 (no detections), 246.6ms
# image 1154/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0848.png: 512x512 (no detections), 242.9ms
# image 1155/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0852.png: 512x512 (no detections), 228.6ms
# image 1156/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0858.png: 512x512 (no detections), 243.9ms
# image 1157/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0860.png: 512x512 (no detections), 247.1ms
# image 1158/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0864.png: 512x512 (no detections), 256.3ms
# image 1159/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0865.png: 512x512 (no detections), 419.8ms
# image 1160/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0870.png: 512x512 (no detections), 385.8ms
# image 1161/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0874.png: 512x512 (no detections), 387.0ms
# image 1162/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0878.png: 512x512 (no detections), 371.6ms
# image 1163/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0880.png: 512x512 (no detections), 378.4ms
# image 1164/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0882.png: 512x512 (no detections), 371.1ms
# image 1165/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0884.png: 512x512 (no detections), 387.3ms
# image 1166/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0891.png: 512x512 (no detections), 391.6ms
# image 1167/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0894.png: 512x512 (no detections), 384.8ms
# image 1168/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0895.png: 512x512 (no detections), 380.6ms
# image 1169/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0912.png: 512x512 (no detections), 377.2ms
# image 1170/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0916.png: 512x512 (no detections), 386.0ms
# image 1171/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0932.png: 512x512 (no detections), 333.5ms
# image 1172/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0938.png: 512x512 (no detections), 239.2ms
# image 1173/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0940.png: 512x512 (no detections), 241.5ms
# image 1174/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0942.png: 512x512 (no detections), 224.4ms
# image 1175/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0945.png: 512x512 (no detections), 235.2ms
# image 1176/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0946.png: 512x512 (no detections), 242.3ms
# image 1177/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0947.png: 512x512 (no detections), 242.6ms
# image 1178/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0951.png: 512x512 (no detections), 258.4ms
# image 1179/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0955.png: 512x512 (no detections), 233.7ms
# image 1180/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0962.png: 512x512 (no detections), 234.6ms
# image 1181/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0966.png: 512x512 (no detections), 249.0ms
# image 1182/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0967.png: 512x512 (no detections), 260.7ms
# image 1183/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0970.png: 512x512 (no detections), 267.8ms
# image 1184/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0971.png: 512x512 (no detections), 246.8ms
# image 1185/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0974.png: 512x512 (no detections), 294.7ms
# image 1186/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x0988.png: 512x512 (no detections), 285.0ms
# image 1187/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x1003.png: 512x512 (no detections), 239.9ms
# image 1188/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x1006.png: 512x512 (no detections), 251.8ms
# image 1189/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x1014.png: 512x512 (no detections), 253.9ms
# image 1190/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x1020.png: 512x512 (no detections), 250.0ms
# image 1191/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x1022.png: 512x512 (no detections), 241.6ms
# image 1192/1192 /content/drive/MyDrive/ship_detection/yolo_data/test/x1025.png: 512x512 (no detections), 261.4ms
# Speed: 0.9ms pre-process, 284.1ms inference, 0.2ms NMS per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/exp4

# %%
import re
import numpy as np

with open("runs/detect/text_results/detect_exp4.txt", 'r') as f:
  data = f.read().splitlines()

detection_results = [' '.join(l.split(" ")[4:6]) for l in data]
np.unique(detection_results)
# Out:
# array(['(no detections),', '512x512 (no'], dtype='<U16')

# %% [markdown]
# Note that all values for the training data result in '(no detections)'. The single outlier is an artifact of the name of the file and is therefore not being parsed correctly.
